# %%
import cv2
from PIL import Image

# %%
import os

# %%
input_folder = "./original"
output_folder = "./images"

# %%
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".jpg", ".png", ".jpeg")):
        img = Image.open(os.path.join(input_folder, filename))
        name = os.path.splitext(filename)[0]
        img.save(os.path.join(output_folder, f"./png/{name}.png"))
        img.save(os.path.join(output_folder, f"./jpg/{name}.jpg"), quality=95)
        print(f"Done: {filename}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 for filename in os.listdir(input_folder):
#       2     if filename.lower().endswith((".jpg", ".png",  ".jpeg")):
#       3         img = Image.open(os.path.join(input_folder, filename))
#       4         name = os.path.splitext(filename)[0]
# ----> 5         img.save(os.path.join(output_folder, f"./png/{name}.png"))
#       6         img.save(os.path.join(output_folder, f"./jpg/{name}.jpg"), quality=95)
#       7         print(f"Done: {filename}")
#
# File ~/miniconda3/envs/dipr/lib/python3.11/site-packages/PIL/Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/./png/image_4.png'
