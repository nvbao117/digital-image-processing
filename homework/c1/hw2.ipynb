# %%
import cv2
import numpy as np
import os

# %% [markdown]
# ## 1. Read Image and show each image on each window

# %%
image_dir = "./images/jpg"

# %%
for filename in os.listdir(image_dir):
    img = cv2.imread(os.path.join(image_dir, filename))
    cv2.imshow(filename, img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# QFontDatabase: Cannot find font directory /home/paro/miniconda3/envs/dipr/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/paro/miniconda3/envs/dipr/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/paro/miniconda3/envs/dipr/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/paro/miniconda3/envs/dipr/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ...

# %% [markdown]
# ## 2. Separate RGB image to 3 layers and show ench layer on ech window

# %%
img = cv2.imread("images/jpg/image_1.jpg")
b, g, r = cv2.split(img)

cv2.imshow("Red", r)
cv2.imshow("Green", g)
cv2.imshow("Blue", b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 3. Convert RGB image to grey and show it

# %%
img = cv2.imread("images/jpg/image_1.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Grayscale", img_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 4. Rotate an image in 100 times (or Esc key to exit): each step, rotated 5

# %%
img = cv2.imread("images/jpg/image_1.jpg")
h, w = img.shape[:2]
center = (w // 2, h // 2)
angle = 0
for _ in range(100):
    angle += 5
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(img, M, (w, h))
    cv2.imshow("Rotating", rotated)
    key = cv2.waitKey(100)
    if key == 27:
        break

cv2.destroyAllWindows()

# %% [markdown]
# ## 5. Read an image, then crop image with 1⁄4 its size from image center and then show it.

# %%
img = cv2.imread("images/jpg/image_1.jpg")
h, w = img.shape[:2]
crop_w, crop_h = w // 2, h // 2

x1 = (w - crop_w) // 2
y1 = (h - crop_h) // 2

cropped = img[y1 : y1 + crop_h, x1 : x1 + crop_w]
cv2.imshow("Original", img)
cv2.imshow("Cropped", cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
